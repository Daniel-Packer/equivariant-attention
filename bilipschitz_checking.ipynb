# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from bilipschitz_checking import *

# %%
rng = np.random.default_rng(seed=123)
N = 1000
d = 2

# fold_input_distances, fold_output_distances = get_distances(N, 2, 1., method='fold')
# invproj_input_distances, invproj_output_distances = get_distances(N, 2, 1., method='inv_proj')
stereo_input_distances, stereo_output_distances = get_distances(N, d, 3, method='stereographic')


plt.scatter(stereo_input_distances, stereo_output_distances, s=1.)

# %%
# plt.scatter(fold_input_distances, fold_output_distances)
# plt.scatter(invproj_input_distances, invproj_output_distances)
plt.scatter(stereo_input_distances, stereo_output_distances, s=1.)

# %%
samples = uniform_ball_samples(1000, 2, 2.)

# %%
sphere_samples = ball_to_sphere(samples, method="stereographic")

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(sphere_samples[:, 0], sphere_samples[:, 1], sphere_samples[:, 2], s=2)
ax.set(aspect='equal')
# Out:
# [None]

# %%
fig, ax = plt.subplots()
ax.scatter(samples[:, 0], samples[:, 1])
ax.set(aspect='equal')
plt.show()
